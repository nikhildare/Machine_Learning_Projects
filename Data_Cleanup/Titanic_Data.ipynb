# %%
#Importing the data dataset

# %%
import pandas as pd

# %%
import numpy as np

# %%
#firstly we will concat the two data frames with df as df1 and df2

# %%
df1=pd.read_csv(r'C:\Users\Sony\Desktop\Self_Learning\Nikhil_Data_Science\DATA_SCIENCE_FOR_GITHUB\Titanic_Data_Visualisation/train.csv', header=0, dtype={"Age":np.float64})
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=pd.read_csv(r'C:\Users\Sony\Desktop\Self_Learning\Nikhil_Data_Science\DATA_SCIENCE_FOR_GITHUB\Titanic_Data_Visualisation/test.csv', header=0, dtype={"Age":np.float64})
df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df=pd.concat([df1,df2], ignore_index=True, sort  = False)
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#here if we are concat the two data frames and we write igonore index with will help as to ignore index of test  data set when appending

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
del df["Name"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1       0.0       3    male  22.0      1      0
# 1            2       1.0       1  female  38.0      1      0
# 2            3       1.0       3  female  26.0      0      0
# 3            4       1.0       1  female  35.0      1      0
# 4            5       0.0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del df["Fare"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1       0.0       3    male  22.0      1      0
# 1            2       1.0       1  female  38.0      1      0
# 2            3       1.0       3  female  26.0      0      0
# 3            4       1.0       1  female  35.0      1      0
# 4            5       0.0       3    male  35.0      0      0
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
del df["Ticket"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1       0.0       3    male  22.0      1      0   NaN        S
# 1            2       1.0       1  female  38.0      1      0   C85        C
# 2            3       1.0       3  female  26.0      0      0   NaN        S
# 3            4       1.0       1  female  35.0      1      0  C123        S
# 4            5       0.0       3    male  35.0      0      0   NaN        S

# %%
del df["Cabin"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1       0.0       3    male  22.0      1      0        S
# 1            2       1.0       1  female  38.0      1      0        C
# 2            3       1.0       3  female  26.0      0      0        S
# 3            4       1.0       1  female  35.0      1      0        S
# 4            5       0.0       3    male  35.0      0      0        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived       418
# Pclass           0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Embarked         2
# dtype: int64

# %%
def getnumber(str):
    if str=="male":
        return 1
    else:
        return 2
    
df["Gender"]=df["Sex"].apply(getnumber)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1       0.0       3    male  22.0      1      0        S       1
# 1            2       1.0       1  female  38.0      1      0        C       2
# 2            3       1.0       3  female  26.0      0      0        S       2
# 3            4       1.0       1  female  35.0      1      0        S       2
# 4            5       0.0       3    male  35.0      0      0        S       1

# %%
del df["Sex"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1       0.0       3  22.0      1      0        S       1
# 1            2       1.0       1  38.0      1      0        C       2
# 2            3       1.0       3  26.0      0      0        S       2
# 3            4       1.0       1  35.0      1      0        S       2
# 4            5       0.0       3  35.0      0      0        S       1

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived       418
# Pclass           0
# Age            263
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
means=df[df.Survived==1].Age.mean()

# %%
means
# Out:
# 28.343689655172415

# %%
#the mean of survival isfind through the means

# %%
df["Age"]=np.where(pd.isnull(df.Age) & df["Survived"]==1 , means, df["Age"])

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived       418
# Pclass           0
# Age            211
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
meanNS=df[df.Survived==1].Age.mean

# %%
df.Age.fillna(meanNS, inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived       418
# Pclass           0
# Age              0
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1       0.0       3  22.0      1      0        S       1
# 1            2       1.0       1  38.0      1      0        C       2
# 2            3       1.0       3  26.0      0      0        S       2
# 3            4       1.0       1  35.0      1      0        S       2
# 4            5       0.0       3  35.0      0      0        S       1

# %%
survivedQ=df[df.Embarked=="Q"][df.Survived==1].shape[0]
survivedS=df[df.Embarked=="S"][df.Survived==1].shape[0]
survivedC=df[df.Embarked=="C"][df.Survived==1].shape[0]
nsurvivedQ=df[df.Embarked=="Q"][df.Survived==0].shape[0]
nsurvivedS=df[df.Embarked=="S"][df.Survived==0].shape[0]
nsurvivedC=df[df.Embarked=="C"][df.Survived==0].shape[0]
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\3677261288.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ=df[df.Embarked=="Q"][df.Survived==1].shape[0]
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\3677261288.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS=df[df.Embarked=="S"][df.Survived==1].shape[0]
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\3677261288.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC=df[df.Embarked=="C"][df.Survived==1].shape[0]
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\3677261288.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nsurvivedQ=df[df.Embarked=="Q"][df.Survived==0].shape[0]
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\3677261288.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
print(survivedQ)
print(survivedC)
print(survivedS)
print(nsurvivedQ)
print(nsurvivedC)
print(nsurvivedS)
# Out:
# 30
# 93
# 217
# 47
# 75
# 427

# %%
df.shape
# Out:
# (1309, 8)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (889, 8)

# %%
def getnumber(str):
    if str=="S":
        return 0
    if str=="C":
        return 1
    else:
        return 2
    
df["embark"]=df["Embarked"].apply(getnumber)

# %%
del df["Embarked"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                    Age  SibSp  Parch  Gender  \
# 0                                                 22.0      1      0       1
# 1                                                 38.0      1      0       2
# 2                                                 26.0      0      0       2
# 3                                                 35.0      1      0       2
# 4                                                 35.0      0      0       1
# ...

# %%
import matplotlib.pyplot as plt

# %%
males=(df["Gender"]==1).sum()

# %%
print(males)
# Out:
# 577

# %%
females=(df["Gender"]==2).sum()

# %%
print(females)
# Out:
# 312

# %%
p=[males,females]

# %%
plt.pie(p,labels=['males','females'], colors=['green', 'blue'], explode=(0.15, 0), startangle=0)
plt.axis('equal')
plt.show()

# %%
MaleS=df[df.Gender==1][df.Survived==1].shape[0]
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\2950374553.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleS=df[df.Gender==1][df.Survived==1].shape[0]

# %%
print(MaleS)
# Out:
# 109

# %%
MaleNS=df[df.Gender==1][df.Survived==0].shape[0]
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\680455821.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleNS=df[df.Gender==1][df.Survived==0].shape[0]

# %%
print(MaleNS)
# Out:
# 468

# %%
FemaleSr=df[df.Gender==2][df.Survived==1].shape[0]
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\2842121181.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleSr=df[df.Gender==2][df.Survived==1].shape[0]

# %%
FemaleSr
# Out:
# 231

# %%
FemaleNSr=df[df.Gender==2][df.Survived==0].shape[0]
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_5832\1177449988.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleNSr=df[df.Gender==2][df.Survived==0].shape[0]

# %%
FemaleNSr
# Out:
# 81

# %%
p=[MaleS,MaleNS,FemaleSr,FemaleNSr]
plt.pie(p,labels=['MaleS','MaleNS','FemaleSr','FemaleNSr'], colors=['red', 'blue','green','yellow'],startangle=100,counterclock=False,autopct="%.2f%%)
plt.axis('equal')
plt.show()
# Out:
#   Input In [60]
#     plt.pie(p,labels=['MaleS','MaleNS','FemaleSr','FemaleNSr'], colors=['red', 'blue','green','yellow'],startangle=100,counterclock=False,autopct="%.2f%%)
#                                                                                                                                                           ^
# SyntaxError: EOL while scanning string literal
